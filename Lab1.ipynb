# %% [markdown]
# # Lab 1: Logistic Regression

# %% [markdown]
# ## Lab Instruction
#
# In this lab, you are to create a logistic regression model to predict the sale price of <br>
# houses (Low, High) from a given set of attributes. <br>
# The data file is`lab1_dataset.csv` <br>
# Note that you need to explore and process/drop attributes, <br>
# and map numerical values of sale prices to categorical values (Low, High)

# %% [markdown]
# ###  1. Import the Dataset and Learn About the Data

# %%
import pandas as pd
dataIn = pd.read_csv("lab1_dataset.csv",sep=",")
print(dataIn.shape)
dataIn.head(10)
# Out:
# (1460, 22)
#    Id Foundation  1stFlrSF KitchenQual  Fireplaces HeatingQC  FullBath  \
# 0   1      PConc       856          Gd           0        Ex         2
# 1   2     CBlock      1262          TA           1        Ex         2
# 2   3      PConc       920          Gd           1        Ex         2
# 3   4     BrkTil       961          Gd           1        Gd         1
# 4   5      PConc      1145          Gd           1        Ex         2
# 5   6       Wood       796          TA           0        Ex         1
# 6   7      PConc      1694          Gd           1        Ex         2
# 7   8     CBlock      1107          TA           2        Ex         2
# 8   9     BrkTil      1022          TA           2        Gd         2
# 9  10     BrkTil      1077          TA           2        Ex         1
#
#   BsmtQual  OpenPorchSF  GarageYrBlt    ...     BsmtFinType1  YearBuilt  \
# 0       Gd           61       2003.0    ...              GLQ       2003
# 1       Gd            0       1976.0    ...              ALQ       1976
# 2       Gd           42       2001.0    ...              GLQ       2001
# 3       TA           35       1998.0    ...              ALQ       1915
# 4       Gd           84       2000.0    ...              GLQ       2000
# 5       Gd           30       1993.0    ...              GLQ       1993
# 6       Ex           57       2004.0    ...              GLQ       2004
# 7       Gd          204       1973.0    ...              ALQ       1973
# 8       TA            0       1931.0    ...              Unf       1931
# 9       TA            4       1939.0    ...              GLQ       1939
#
#   GarageArea  TotRmsAbvGrd  GarageCars  GrLivArea  YearRemodAdd  LotFrontage  \
# 0        548             8           2       1710          2003         65.0
# 1        460             6           2       1262          1976         80.0
# 2        608             6           2       1786          2002         68.0
# 3        642             7           3       1717          1970         60.0
# 4        836             9           3       2198          2000         84.0
# 5        480             5           2       1362          1995         85.0
# 6        636             7           2       1694          2005         75.0
# 7        484             7           2       2090          1973          NaN
# 8        468             8           2       1774          1950         51.0
# 9        205             5           1       1077          1950         50.0
#
#    Fence  SalePrice
# 0    NaN     208500
# 1    NaN     181500
# 2    NaN     223500
# 3    NaN     140000
# 4    NaN     250000
# 5  MnPrv     143000
# 6    NaN     307000
# 7    NaN     200000
# 8    NaN     129900
# 9    NaN     118000
#
# [10 rows x 22 columns]

# %% [markdown]
# ###  2. Preprocessing
#
# Use techniques that you have learned to preprocess the data. For example,
# -  Remove non-informative features
# -  Remove features with too many NA
# -  Remove rows with incomplete data
# -  Remove features with highly unbalanced labels
# -  Encode categorical variables as appropriate

# %%
print("NA Percentage(%)")
print((dataIn.isna().sum()/dataIn.shape[0])*100)
# Out:
# NA Percentage(%)
# Id               0.000000
# Foundation       0.000000
# 1stFlrSF         0.000000
# KitchenQual      0.000000
# Fireplaces       0.000000
# HeatingQC        0.000000
# FullBath         0.000000
# BsmtQual         2.534247
# OpenPorchSF      0.000000
# GarageYrBlt      5.547945
# ExterQual        0.000000
# OverallQual      0.000000
# BsmtFinType1     2.534247
# YearBuilt        0.000000
# GarageArea       0.000000
# TotRmsAbvGrd     0.000000
# GarageCars       0.000000
# GrLivArea        0.000000
# YearRemodAdd     0.000000
# LotFrontage     17.739726
# Fence           80.753425
# SalePrice        0.000000
# dtype: float64

# %% [markdown]
# We will see the column Fence has too many Na (About 80%) then drop it

# %%
#ID cannot use to predict
clean_nonInformative = dataIn.drop(['Id','Fence'],axis=1)# fence too many NaN

# %%
# Clean row that has Na value
clean_row_na = clean_nonInformative.dropna(how='any')
clean_row_na.select_dtypes(exclude = ['int64','float64']).describe()
# Out:
#        Foundation KitchenQual HeatingQC BsmtQual ExterQual BsmtFinType1
# count        1103        1103      1103     1103      1103         1103
# unique          5           4         5        4         4            6
# top         PConc          TA        Ex       TA        TA          Unf
# freq          527         528       602      486       647          347

# %% [markdown]
# Replace All String(Text) with number(Encode)

# %%
codebook1 = {'Ex':5,'Gd':4,'TA':3,'Fa':2,'Po':1} # Excellent, Good, Typical, Fair, Poor
codebook2 = {'Unf':5,'GLQ':6,'ALQ':4,'BLQ':3,'Rec':2,'LwQ':1}
codebook3 = {'PConc':6,'CBlock':5,'Slab':4,'BrkTil':3,'Stone':2,'Wood':1 }
data_encode1 = clean_row_na.replace(codebook1)
data_encode1 = data_encode1.replace(codebook2)
data_encode1 = data_encode1.replace(codebook3)

# %%
data_encode1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1103 entries, 0 to 1459
# Data columns (total 20 columns):
# Foundation      1103 non-null int64
# 1stFlrSF        1103 non-null int64
# KitchenQual     1103 non-null int64
# Fireplaces      1103 non-null int64
# HeatingQC       1103 non-null int64
# FullBath        1103 non-null int64
# BsmtQual        1103 non-null int64
# OpenPorchSF     1103 non-null int64
# GarageYrBlt     1103 non-null float64
# ExterQual       1103 non-null int64
# OverallQual     1103 non-null int64
# BsmtFinType1    1103 non-null int64
# YearBuilt       1103 non-null int64
# GarageArea      1103 non-null int64
# TotRmsAbvGrd    1103 non-null int64
# GarageCars      1103 non-null int64
# GrLivArea       1103 non-null int64
# YearRemodAdd    1103 non-null int64
# LotFrontage     1103 non-null float64
# SalePrice       1103 non-null int64
# dtypes: float64(2), int64(18)
# memory usage: 181.0 KB

# %%
#Get Correclation Coefficient
data_encode1.corr()
# Out:
#               Foundation  1stFlrSF  KitchenQual  Fireplaces  HeatingQC  \
# Foundation      1.000000  0.246327     0.427370    0.087739   0.392207
# 1stFlrSF        0.246327  1.000000     0.431974    0.411319   0.237949
# KitchenQual     0.427370  0.431974     1.000000    0.254813   0.526647
# Fireplaces      0.087739  0.411319     0.254813    1.000000   0.117549
# HeatingQC       0.392207  0.237949     0.526647    0.117549   1.000000
# FullBath        0.378727  0.380589     0.480521    0.248364   0.391940
# BsmtQual        0.538511  0.418787     0.601512    0.251890   0.449567
# OpenPorchSF     0.187537  0.253056     0.303399    0.182439   0.203020
# GarageYrBlt     0.639916  0.282649     0.539539    0.054968   0.480916
# ExterQual       0.457853  0.447886     0.731453    0.249405   0.536638
# OverallQual     0.415245  0.530052     0.688514    0.408299   0.490624
# BsmtFinType1    0.332235  0.198490     0.434193    0.083081   0.376162
# YearBuilt       0.755376  0.310802     0.537917    0.125358   0.470784
# GarageArea      0.367550  0.528705     0.498482    0.214000   0.304968
# TotRmsAbvGrd    0.093836  0.401160     0.325434    0.357647   0.182228
# GarageCars      0.402132  0.472730     0.513012    0.255745   0.338390
# GrLivArea       0.166008  0.562564     0.446396    0.471115   0.272414
# YearRemodAdd    0.481240  0.285764     0.651935    0.110822   0.559963
# LotFrontage     0.095283  0.454168     0.178428    0.260670   0.102429
# SalePrice       0.406993  0.619564     0.670606    0.457045   0.441388
#
#               FullBath  BsmtQual  OpenPorchSF  GarageYrBlt  ExterQual  \
# Foundation    0.378727  0.538511     0.187537     0.639916   0.457853
# 1stFlrSF      0.380589  0.418787     0.253056     0.282649   0.447886
# KitchenQual   0.480521  0.601512     0.303399     0.539539   0.731453
# Fireplaces    0.248364  0.251890     0.182439     0.054968   0.249405
# HeatingQC     0.391940  0.449567     0.203020     0.480916   0.536638
# FullBath      1.000000  0.537259     0.293259     0.500534   0.526565
# BsmtQual      0.537259  1.000000     0.318406     0.680921   0.675088
# OpenPorchSF   0.293259  0.318406     1.000000     0.256656   0.346758
# GarageYrBlt   0.500534  0.680921     0.256656     1.000000   0.592124
# ExterQual     0.526565  0.675088     0.346758     0.592124   1.000000
# OverallQual   0.596794  0.696068     0.341708     0.563078   0.749724
# BsmtFinType1  0.373041  0.466538     0.204459     0.481126   0.463264
# YearBuilt     0.502974  0.733237     0.237983     0.825655   0.611248
# GarageArea    0.446991  0.514962     0.304330     0.592075   0.514185
# TotRmsAbvGrd  0.543429  0.293285     0.253694     0.165136   0.348870
# GarageCars    0.523427  0.578277     0.261293     0.602562   0.546448
# GrLivArea     0.617865  0.410331     0.355856     0.238410   0.467655
# YearRemodAdd  0.482489  0.596983     0.261145     0.650934   0.607802
# LotFrontage   0.191959  0.175717     0.162388     0.067910   0.168620
# SalePrice     0.576740  0.673221     0.342930     0.501952   0.697453
#
#               OverallQual  BsmtFinType1  YearBuilt  GarageArea  TotRmsAbvGrd  \
# Foundation       0.415245      0.332235   0.755376    0.367550      0.093836
# 1stFlrSF         0.530052      0.198490   0.310802    0.528705      0.401160
# KitchenQual      0.688514      0.434193   0.537917    0.498482      0.325434
# Fireplaces       0.408299      0.083081   0.125358    0.214000      0.357647
# HeatingQC        0.490624      0.376162   0.470784    0.304968      0.182228
# FullBath         0.596794      0.373041   0.502974    0.446991      0.543429
# BsmtQual         0.696068      0.466538   0.733237    0.514962      0.293285
# OpenPorchSF      0.341708      0.204459   0.237983    0.304330      0.253694
# GarageYrBlt      0.563078      0.481126   0.825655    0.592075      0.165136
# ExterQual        0.749724      0.463264   0.611248    0.514185      0.348870
# OverallQual      1.000000      0.465821   0.591263    0.557981      0.461954
# BsmtFinType1     0.465821      1.000000   0.456296    0.350416      0.158211
# YearBuilt        0.591263      0.456296   1.000000    0.470979      0.115802
# GarageArea       0.557981      0.350416   0.470979    1.000000      0.387965
# TotRmsAbvGrd     0.461954      0.158211   0.115802    0.387965      1.000000
# GarageCars       0.606923      0.390407   0.533834    0.841350      0.429274
# GrLivArea        0.609356      0.225019   0.198666    0.488049      0.826884
# YearRemodAdd     0.568965      0.477802   0.628760    0.414426      0.180646
# LotFrontage      0.243030      0.055605   0.108390    0.357657      0.355530
# SalePrice        0.796727      0.395645   0.522975    0.622847      0.557245
#
#               GarageCars  GrLivArea  YearRemodAdd  LotFrontage  SalePrice
# Foundation      0.402132   0.166008      0.481240     0.095283   0.406993
# 1stFlrSF        0.472730   0.562564      0.285764     0.454168   0.619564
# KitchenQual     0.513012   0.446396      0.651935     0.178428   0.670606
# Fireplaces      0.255745   0.471115      0.110822     0.260670   0.457045
# HeatingQC       0.338390   0.272414      0.559963     0.102429   0.441388
# FullBath        0.523427   0.617865      0.482489     0.191959   0.576740
# BsmtQual        0.578277   0.410331      0.596983     0.175717   0.673221
# OpenPorchSF     0.261293   0.355856      0.261145     0.162388   0.342930
# GarageYrBlt     0.602562   0.238410      0.650934     0.067910   0.501952
# ExterQual       0.546448   0.467655      0.607802     0.168620   0.697453
# OverallQual     0.606923   0.609356      0.568965     0.243030   0.796727
# BsmtFinType1    0.390407   0.225019      0.477802     0.055605   0.395645
# YearBuilt       0.533834   0.198666      0.628760     0.108390   0.522975
# GarageArea      0.841350   0.488049      0.414426     0.357657   0.622847
# TotRmsAbvGrd    0.429274   0.826884      0.180646     0.355530   0.557245
# GarageCars      1.000000   0.496401      0.474682     0.287260   0.653542
# GrLivArea       0.496401   1.000000      0.286824     0.397756   0.706224
# YearRemodAdd    0.474682   0.286824      1.000000     0.083494   0.519257
# LotFrontage     0.287260   0.397756      0.083494     1.000000   0.345894
# SalePrice       0.653542   0.706224      0.519257     0.345894   1.000000

# %% [markdown]
# Check Unbalance Label

# %%
print(data_encode1['Foundation'].value_counts(1))
cleaned_high_unb1 = data_encode1.drop('Foundation',axis=1)
# Out:
# 6    0.477788
# 5    0.404352
# 3    0.110607
# 2    0.005440
# 1    0.001813
# Name: Foundation, dtype: float64

# %%
print(data_encode1['KitchenQual'].value_counts(1))
# Out:
# 3    0.478694
# 4    0.418858
# 5    0.083409
# 2    0.019039
# Name: KitchenQual, dtype: float64

# %%
print(data_encode1['HeatingQC'].value_counts(1))
cleaned_high_unb2 = cleaned_high_unb1.drop(['HeatingQC'],axis=1)
# Out:
# 5    0.545784
# 3    0.270172
# 4    0.158658
# 2    0.024479
# 1    0.000907
# Name: HeatingQC, dtype: float64

# %%
print(data_encode1['BsmtQual'].value_counts(1))
# Out:
# 3    0.440617
# 4    0.427017
# 5    0.103354
# 2    0.029012
# Name: BsmtQual, dtype: float64

# %%
print(data_encode1['ExterQual'].value_counts(1))
# Out:
# 3    0.586582
# 4    0.364461
# 5    0.042611
# 2    0.006346
# Name: ExterQual, dtype: float64

# %%
print(data_encode1['BsmtFinType1'].value_counts(1))
# Out:
# 5    0.314597
# 6    0.297371
# 4    0.146872
# 3    0.095195
# 2    0.095195
# 1    0.050771
# Name: BsmtFinType1, dtype: float64

# %%
cleaned_high_unb2.head(20).shape
# Out:
# (20, 18)

# %%
cleaned_data = cleaned_high_unb2
cleaned_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1103 entries, 0 to 1459
# Data columns (total 18 columns):
# 1stFlrSF        1103 non-null int64
# KitchenQual     1103 non-null int64
# Fireplaces      1103 non-null int64
# FullBath        1103 non-null int64
# BsmtQual        1103 non-null int64
# OpenPorchSF     1103 non-null int64
# GarageYrBlt     1103 non-null float64
# ExterQual       1103 non-null int64
# OverallQual     1103 non-null int64
# BsmtFinType1    1103 non-null int64
# YearBuilt       1103 non-null int64
# GarageArea      1103 non-null int64
# TotRmsAbvGrd    1103 non-null int64
# GarageCars      1103 non-null int64
# GrLivArea       1103 non-null int64
# YearRemodAdd    1103 non-null int64
# LotFrontage     1103 non-null float64
# SalePrice       1103 non-null int64
# dtypes: float64(2), int64(16)
# memory usage: 163.7 KB

# %% [markdown]
# ### 3. Model Training
# We will use Scikit-learn package to build a model.
# - http://scikit-learn.org/stable/
#
# Model Evaluation Method
# - Split into train set and test set

# %%
data_x = cleaned_data.drop(['SalePrice'],axis = 1)
data_y = cleaned_data.SalePrice

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(data_x, data_y, test_size = 0.4)
print("Train:",x_train.shape, y_train.shape) 
print("Test:",x_test.shape, y_test.shape)
# Out:
# Train: (661, 17) (661,)
# Test: (442, 17) (442,)

# %% [markdown]
# - Fit Logistic Regression model

# %%
from sklearn import linear_model

lr = linear_model.LogisticRegression()
lr.fit(x_train,y_train)

yhat_test = lr.predict(x_test)
yhat_train = lr.predict(x_train)
# print(y_test)
# print(yhat_test)
# print(y_train)
# print(yhat_train)

# %% [markdown]
# ### 4. Model Tuning &  Result Analysis
#
# Analyze the model results. Do you think the model is good enough? <br>
# Does it overfit or underfit the data? <br>
# Explain and provide evidence to support your claims.

# %%
from sklearn.metrics import accuracy_score

acc_train = accuracy_score(y_train,yhat_train)
print("Accuracy score for train dataset:{} %".format('%0.2f'%(acc_train*100)))
acc_train = accuracy_score(y_test,yhat_test)
print("Accuracy score for train dataset:{} %".format('%0.2f'%(acc_train*100)))
# Out:
# Accuracy score for train dataset:64.90 %
# Accuracy score for train dataset:1.13 %

# %% [markdown]
# Model is Overfitting because the equation in the model was tuning to fit the training_set already. When the testing_set(other data) come the model cannot fit the data then the accuracy is about 0.5-1% but the model can predict the trend then we have to define price to range ex. 0-10000 is low, 10001-20000 is medium, >20001 is high

# %% [markdown]
# ### 5. (Optional) Mutlinomial Logistic Regression Model
#
# Binning the sale price into three classes : `Low`, `Medium`, `High`.
# Then, apply the logistic regression model and evaluate the model performance. <br>
# See http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html

# %%
cleaned_data.loc[cleaned_data['SalePrice'] > 0 AND cleaned_data['SalePrice'] < 10000, 'SalePrice'] = 0
# Out:
#   File "<ipython-input-251-fbe69e946a51>", line 1
#     cleaned_data.loc[cleaned_data['SalePrice'] > 0 AND cleaned_data['SalePrice'] < 10000, 'SalePrice'] = 0
#                                                      ^
# SyntaxError: invalid syntax
